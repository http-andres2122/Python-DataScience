# %%
import tweepy

# %%
tweepy
# Out:
# <module 'tweepy' from '/usr/local/lib/python3.10/dist-packages/tweepy/__init__.py'>

# %%
#import keys

consumer_key = "24bD50HnGHk6Eyx1ZqpBGI5f9"
consumer_secret= "pz4wD0DlmdDbF2T6rNCeK25y60wtXtANNij3kpEFYknuXyDOzz"
access_token = "462232403-IxyGlCRrR4jtZ0WalrQJlJOfurTOq9XoRA0Oszhe"
access_token_secret = "wZnS6ZLvnk5Q0bIMwWzK0FwhVrL9ywsoXrNDnEzwEwQh0"

# %%
consumer_key
# Out:
# '24bD50HnGHk6Eyx1ZqpBGI5f9'

# %%
#auth OAuth 1.0a
client = tweepy.Client(
    consumer_key = "24bD50HnGHk6Eyx1ZqpBGI5f9",
    consumer_secret= "pz4wD0DlmdDbF2T6rNCeK25y60wtXtANNij3kpEFYknuXyDOzz",
    access_token = "462232403-IxyGlCRrR4jtZ0WalrQJlJOfurTOq9XoRA0Oszhe",
    access_token_secret = "wZnS6ZLvnk5Q0bIMwWzK0FwhVrL9ywsoXrNDnEzwEwQh0"
)

# %%
#auth version 2
auth = tweepy.OAuth1UserHandler(
    consumer_key, consumer_secret, access_token, access_token_secret
)

# %%
#bear method
client = tweepy.Client("AAAAAAAAAAAAAAAAAAAAANsqpQEAAAAAa8o3sCnK%2B77je7vU2u6PpjM4g%2BE%3De5rhX5xoFZoE9vrZ9Rq5T4V2wVHJNW3g62St28HdY08AERYnoR")

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(client)

# %%
timeline = api.home_timeline(count=10)
for tweet in timeline:
    print(tweet.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-5fe6516921d3> in <cell line: 1>()
# ----> 1 timeline = api.home_timeline(count=10)
#       2 for tweet in timeline:
#       3     print(tweet.text)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
# ...

# %%
tweet_text = "¡Hola, Twitter! Este es un tweet de ejemplo usando Tweepy y Python."
api.update_status(status=tweet_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-ee6d85962652> in <cell line: 2>()
#       1 tweet_text = "¡Hola, Twitter! Este es un tweet de ejemplo usando Tweepy y Python."
# ----> 2 api.update_status(status=tweet_text)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in update_status(self, status, **kwargs)
#    1140             kwargs['media_ids'] = list_to_csv(kwargs['media_ids'])
#    1141
# -> 1142         return self.request(
# ...

# %%
public_tweets = api.home_timeline()

for tweet in public_tweets:
    print(tweet.text)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-43-72f16552d538> in <cell line: 1>()
# ----> 1 public_tweets = api.home_timeline()
#       2
#       3 for tweet in public_tweets:
#       4     print(tweet.text)
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
# ...

# %%
resultados = api.search_tweets(q='AluraOnline')
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-42-1d23c4e11330> in <cell line: 1>()
# ----> 1 resultados = api.search_tweets(q='AluraOnline')
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ...

# %%
twitter = tweepy.API(client)

# %%
twitter.search_tweets(q='AluraOnline')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-316d10ef8fa4> in <cell line: 1>()
# ----> 1 twitter.search_tweets(q='AluraOnline')
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ...

# %%
#auth api's consumer and token mixto
authentication = tweepy.OAuthHandler(consumer_key, consumer_secret)
authentication.set_access_token(access_token, access_token_secret)

# %%
authentication

# %%
#variable twitter conect on api verify
twitter = tweepy.API(authentication)

# %%
twitter.search_tweets(q='AluraOnline')
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-34-316d10ef8fa4> in <cell line: 1>()
# ----> 1 twitter.search_tweets(q='AluraOnline')
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ...
