# %%
import pandas as pd

# %%
list('fegrgdsfdsfdsgdsfsddasda')
# Out:
# ['f',
#  'e',
#  'g',
#  'r',
#  'g',
#  'd',
#  's',
#  'f',
#  'd',
#  's',
#  'f',
#  'd',
#  's',
#  'g',
#  'd',
#  's',
#  'f',
#  's',
#  'd',
#  'd',
#  'a',
#  's',
#  'd',
#  'a']

# %%
s = pd.Series(list('fegrgdsfdsfdsgdsfsddasda'))
s
# Out:
# 0     f
# 1     e
# 2     g
# 3     r
# 4     g
# 5     d
# 6     s
# 7     f
# 8     d
# 9     s
# 10    f
# 11    d
# 12    s
# 13    g
# 14    d
# 15    s
# 16    f
# 17    s
# 18    d
# 19    d
# 20    a
# 21    s
# 22    d
# 23    a
# dtype: object

# %%
#traer unicos elementos de la seri
s.unique()
# Out:
# array(['f', 'e', 'g', 'r', 'd', 's', 'a'], dtype=object)

# %%
#frecuencia de elementos de la serie, cantidad de veces que se repite dichos elementos
s.value_counts()
# Out:
# d    7
# s    6
# f    4
# g    3
# a    2
# e    1
# r    1
# dtype: int64

# %%
datos = pd.read_csv('alquiler_sin_not_null.csv',  sep = ';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento        Comas        2         0       0    50   1300.0
# 5  Casa en condominio          Ate        5         4       5   750  22000.0
# 6  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 7        Departamento      Mi Perú        2         1       0    70   1500.0
# 8        Departamento    San Borja        3         1       1    90   1500.0
# 9        Departamento    San Borja        1         0       1    40   2000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            0.0       0.0
# 2          390.0      20.0
# ...

# %%
#datos unicos en dataframe
datos.Tipo.unique()
# Out:
# array(['Habitación', 'Casa', 'Departamento', 'Casa en condominio',
#        'Casa comercial', 'Casa de villa'], dtype=object)

# %%
#contadores
datos.Tipo.value_counts()
# Out:
# Departamento          18780
# Casa en condominio      996
# Casa                    965
# Habitación              836
# Casa comercial          265
# Casa de villa           249
# Name: Tipo, dtype: int64
