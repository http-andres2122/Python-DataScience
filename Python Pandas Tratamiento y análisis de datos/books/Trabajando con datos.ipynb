# %% [markdown]
# #Trabajando con datos

# %%
#importando pandas
#import pandas as pd
#se usa pd() para llamar a pandas
import pandas as pd
pd.set_option('display.max_columns', 9)
pd.set_option('display.max_rows', 25)
#pd.set_option('display.min_rows', 10)
pd.set_option('display.expand_frame_repr', True)
pd.get_option("display.max_rows")
#se usa pd_set_option para mostrar mas filas y culumnas
# Out:
# 25

# %%
#leyendo archivo csv, usando el metodo csv
pd.read_csv('alquiler.csv')
# Out:
#       Tipo;Distrito;Cuartos;Vacantes;Suites;Area;Valor;Mantenimiento;Impuesto
# 0              Habitación;San Borja;1;0;0;40;1700;500;60
# 1                       Casa;Lurigancho;2;0;1;100;7000;;
# 2           Local comercial;Ate;0;4;0;150;5200;4020;1111
# 3            Departamento;Pachacámac;1;0;0;15;800;390;20
# 4                     Departamento;Ate;1;0;0;48;800;230;
# 5                  Departamento;Barranco;3;1;0;70;1200;;
# 6                Departamento;Comas;2;0;0;50;1300;301;17
# 7               Casa en condominio;Ate;5;4;5;750;22000;;
# 8         Casa en condominio;El Agustino;2;2;0;65;1000;;
# 9      Local comercial;Pachacámac;0;3;0;695;35000;191...
# 10               Departamento;Pachacámac;1;0;0;36;1200;;
# 11             Departamento;Mi Perú;2;1;0;70;1500;642;74
# ...                                                  ...
# 32948    Local comercial;Pachacámac;0;0;0;32;600;1035;83
# 32949        Departamento;Comas;3;1;2;150;15000;1400;600
# ...

# %%
#asignando resultado a un objeto pandas
#se asigna separador con "sep='separador'"
alquiler = pd.read_csv('alquiler.csv', sep=';')

# %%
alquiler
# Out:
#                      Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 0              Habitación    San Borja        1         0       0    40
# 1                    Casa   Lurigancho        2         0       1   100
# 2         Local comercial          Ate        0         4       0   150
# 3            Departamento   Pachacámac        1         0       0    15
# 4            Departamento          Ate        1         0       0    48
# 5            Departamento     Barranco        3         1       0    70
# 6            Departamento        Comas        2         0       0    50
# 7      Casa en condominio          Ate        5         4       5   750
# 8      Casa en condominio  El Agustino        2         2       0    65
# 9         Local comercial   Pachacámac        0         3       0   695
# 10           Departamento   Pachacámac        1         0       0    36
# 11           Departamento      Mi Perú        2         1       0    70
# ...

# %%
#cantidad y estadistica de mi tabla
alquiler.describe()
# Out:
#             Cuartos      Vacantes        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#        Mantenimiento      Impuesto
# count   2.886700e+04  2.272300e+04
# mean    2.388062e+03  2.364410e+03
# std     3.918496e+04  1.795641e+05
# min     1.000000e+00  1.000000e+00
# 25%     5.900000e+02  1.100000e+02
# 50%     9.900000e+02  2.500000e+02
# ...
