# %% [markdown]
# #Importando base de datos

# %%
import pandas as pd

# %%
datos = pd.read_csv('credit_card.csv')

# %%
datos
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Traducciendo variables

# %%
#cambiando nombre de variables

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dic_columnas = {
    'LIMIT_BAL' : 'Limite',
    'CHECKING_ACCOUNT' : 'Cuenta_corriente',
    'EDUCATION' : 'Escolaridad',
    'MARRIAGE' : 'Estado_civil',
    'AGE' : 'Edad',
    'BILL_AMT' : 'Valor_factura',
    'PAY_AMT' : 'Valor_pago',
    'DEFAULT' : 'Moroso'
}

# %%
tarjetas = datos.rename(columns = dic_columnas)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente        Escolaridad Estado_civil  Edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# ##cambiando variables dentro de las columnas

# %%
#llamando valores unicos en columna
tarjetas.Cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dic_cuenta = {
    'Yes' : 'Si' ,
    'No' : 'No'
}

# %%
#generando valor sin atribuir
tarjetas.Cuenta_corriente.map(dic_cuenta)
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: Cuenta_corriente, Length: 1500, dtype: object

# %%
#atribuyendo valores a columna
tarjetas.Cuenta_corriente = tarjetas.Cuenta_corriente.map(dic_cuenta)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente        Escolaridad Estado_civil  Edad  \
# 0    6022               Si       2.University      Married    24
# 1   36132               Si       2.University       Single    26
# 2   27099               Si       2.University       Single    34
# 3   15055               Si       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
#llamando valores unicos de escolaridad
tarjetas.Escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_Escolaridad = {
    '2.University' : '2. Universidad',
    '3.Graduate School' : '3. Post-graduacion',
    '1.High School' : '1. Colegio'
}

# %%
tarjetas.Escolaridad = tarjetas.Escolaridad.map(dic_Escolaridad)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad      Married    24
# 1   36132               Si      2. Universidad       Single    26
# 2   27099               Si      2. Universidad       Single    34
# 3   15055               Si      2. Universidad      Married    37
# 4  150550               No  3. Post-graduacion       Single    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
#llamando datos unicos estado civil
tarjetas.Estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_estado_civil = {
    'Married' : 'Casado/a',
    'Single' : 'Soltero/a'
}

# %%
tarjetas.Estado_civil = tarjetas.Estado_civil.map(dic_estado_civil)

# %%
tarjetas.head(10)
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
# 5   30110               Si      2. Universidad    Soltero/a    23
# 6   42154               Si          1. Colegio     Casado/a    28
# 7   60220               Si          1. Colegio    Soltero/a    34
# 8   78286               Si  3. Post-graduacion    Soltero/a    51
# 9  189693               Si      2. Universidad    Soltero/a    41
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0
# ...

# %%
tarjetas.to_csv('/content/creditos_finales.csv', sep=';', index=False)

# %% [markdown]
# #graficando datos con seaborn

# %%
#comprobando que seaborn este instalado
# !pip install seaborn

# %%
#importando seaborn
import seaborn as sns

# %%
#comprobando version de seaborn
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: missingno

# %%
#comprobando base de datos
tarjetas.shape
# Out:
# (1500, 8)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# #analisis 1

# %%
#gafico de distribuccion con seaborn
sns.distplot(tarjetas['Limite'])
# Out:
# <ipython-input-198-1a5aa1bb30df>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tarjetas['Limite'])
# <Axes: xlabel='Limite', ylabel='Density'>

# %%
#usando version nueva al comando distplot
sns.displot(data = tarjetas, x = 'Limite')
#remover seabor id con punto y coma al final

# %%
#analizando variable de caracter Escolaridad
sns.displot(data = tarjetas, x = 'Limite', hue='Escolaridad');

# %% [markdown]
# #analisis 2

# %%
#creando columna basada en la informacion limite y valor factura
tarjetas['ui'] = tarjetas['Valor_factura'] / tarjetas['Limite']

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        ui
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.displot(data = tarjetas, x='ui')

# %% [markdown]
# Hay un publico significativo que usa poco del limite que tienen disponible

# %% [markdown]
# #Estilos y colores

# %%
sns.set_style('darkgrid')

# %%
sns.displot(data = tarjetas, x = 'Limite', hue='Escolaridad');

# %%
sns.set_style('white')

# %%
sns.displot(data = tarjetas, x = 'Limite', hue='Escolaridad');

# %%
sns.set_style('whitegrid')

# %%
sns.displot(data = tarjetas, x = 'Limite', hue='Escolaridad');

# %%
#cambiar de color las barras en tabla estadistica
#https://matplotlib.org/stable/tutorials/colors/colormaps.html
sns.displot(data = tarjetas, x = 'Limite', hue='Escolaridad', palette='inferno');

# %%
#colores ivertidos inferno
sns.displot(data = tarjetas, x = 'Limite', hue='Escolaridad', palette='inferno_r');

# %% [markdown]
# #Analisis de variables categoricas

# %%
#variables categoricas son los nombres de las columnas
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        ui
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.countplot(x='Cuenta_corriente', data = tarjetas)
# Out:
# <Axes: xlabel='Cuenta_corriente', ylabel='count'>

# %%
#buscando morosos
sns.countplot(x='Cuenta_corriente', data = tarjetas, hue = 'Moroso')
# Out:
# <Axes: xlabel='Cuenta_corriente', ylabel='count'>

# %%
#cambiando colores
sns.countplot(x='Cuenta_corriente', data = tarjetas, hue = 'Moroso', palette = 'coolwarm')
# Out:
# <Axes: xlabel='Cuenta_corriente', ylabel='count'>

# %%
#analizando variable de estado civil
sns.catplot(x='Estado_civil', y='Limite', data=tarjetas)

# %%
#forma mas detalla comparando datos con morosos
sns.catplot(x='Estado_civil', y='Limite', data=tarjetas, hue='Moroso')

# %%
#separando datos hue
sns.catplot(x='Estado_civil', y='Limite', data=tarjetas, hue='Moroso', dodge = True)

# %%
#comparando escolaridad con ui
sns.swarmplot(x='Escolaridad', y='ui', data=tarjetas, palette='inferno');
# Out:
# <ipython-input-219-bbdb3c669740>:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='Escolaridad', y='ui', data=tarjetas, palette='inferno');
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#mas sobre plots
#https://seaborn.pydata.org/generated/seaborn.catplot.html?highlight=catplot#seaborn.catplot

# %%
#comparando escolaridad con ui, pero con boxplot
sns.boxplot(x='Escolaridad', y='ui', data=tarjetas);

# %%
#comparando escolaridad con ui y con moroso
sns.boxplot(x='Escolaridad', y='ui', data=tarjetas, hue='Moroso');

# %%
#comparando escolaridad con ui y con moroso
sns.boxplot(x='Escolaridad', y='ui', data=tarjetas, hue='Moroso', palette='bone');

# %%
#graficando con grafico violin
#el punto blanco representa la media
sns.violinplot(x='Escolaridad', y='ui', data=tarjetas)
# Out:
# <Axes: xlabel='Escolaridad', ylabel='ui'>

# %%
#ahora con moroso
sns.violinplot(x='Escolaridad', y='ui', data=tarjetas, hue='Moroso')
# Out:
# <Axes: xlabel='Escolaridad', ylabel='ui'>

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        ui
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
#analizando edad
tarjetas.Edad.unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
#variable categorica de edad
bins = [20, 30, 40, 50, 100]
nombres = ['20-30', '30-40', '40-50', '50+']

tarjetas['rango_edad'] = pd.cut(tarjetas['Edad'], bins, labels=nombres)

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        ui rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
#limite disponible segun edad
sns.boxplot(x='rango_edad', y='Limite', data=tarjetas)
# Out:
# <Axes: xlabel='rango_edad', ylabel='Limite'>

# %%
#bins = [0, 0.25, 0.50, 0.75, 1]
#nombres = ['0%-25%', '25%-50%', '50%-75%', '75%-100%']

#tarjetas['rango_iu'] = pd.cut(tarjetas['iu'], bins, labels=nombres)

# %% [markdown]
# #analisis de variables numericas

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        ui rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.displot(data=tarjetas, x='Limite')

# %%
#comparando limite y escolaridad
sns.displot(data=tarjetas, x='Limite', hue='Escolaridad')

# %%
#separando columnas por graficos
sns.displot(data=tarjetas, x='Limite', col='Escolaridad')

# %%
#funcion densidad 'kde'
sns.displot(data=tarjetas, x='Limite', col='Escolaridad', kind='kde')

# %%
#analizando variable moroso
sns.displot(data=tarjetas, x='Limite', col='Escolaridad', kind='kde', hue='Moroso')

# %%
#analizando edad
sns.displot(data=tarjetas, x='Limite', col='Escolaridad', kind='kde', hue='rango_edad')

# %% [markdown]
# # ejemplo alura

# %%
sns.displot(data=tarjetas, x='Limite', col='Cuenta_corriente')

# %%
sns.displot(data=tarjetas, x='Limite', hue='Cuenta_corriente')

# %%
#usando parametro kind
sns.displot(data=tarjetas, x='Limite', col='Cuenta_corriente', kind='kde')

# %%
sns.displot(data=tarjetas, x='Limite', hue='Cuenta_corriente', kind='kde')

# %% [markdown]
# #grafico de dispersion Scatterplot y lmplot

# %%
#analizando valor de la factura con relacion al ui
sns.scatterplot(x='ui', y='Valor_factura', data=tarjetas);

# %%
#analizando variable cuenta corriente
sns.scatterplot(x='ui', y='Valor_factura', data=tarjetas, hue='Cuenta_corriente');

# %%
#gafico de dispersion, muestra linea de tendencia
sns.lmplot(x='ui', y='Valor_factura', data=tarjetas)

# %% [markdown]
# #Test de hipótesis

# %%
#test de hipotesis con varibale morosidad
sns.lmplot(x='ui', y='Valor_factura', data=tarjetas, col='Moroso')

# %%
#biblioteca scipy
from scipy.stats import ranksums

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        ui rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %% [markdown]
# H<sup>null<sup>
#
# la distribucion de los grupos moroso y no moroso es la misma

# %% [markdown]
# H<sup>alt<sup>
#
# la distribucion de los grupos moroso y no moroso no es la misma

# %%
#creando grupo moroso y no moroso
moroso = tarjetas.query('Moroso == 1').Valor_factura
moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: Valor_factura, Length: 117, dtype: float64

# %%
no_moroso = tarjetas.query('Moroso == 0').Valor_factura
no_moroso
# Out:
# 2         4223.5297
# 3        14522.9563
# 4       124060.1253
# 5          114.4180
# 6         4244.3056
#            ...
# 1494     32698.2556
# 1496     23637.8555
# 1497       962.9178
# 1498       864.7592
# 1499     97022.8508
# Name: Valor_factura, Length: 1383, dtype: float64

# %%
#funcion ranksums
#los valores abajo de 5% se acepta como hipotesis alternativa aceptada
ranksums(moroso, no_moroso)
# Out:
# RanksumsResult(statistic=-2.562530598426702, pvalue=0.010391243081223555)

# %%
resultado = ranksums(moroso, no_moroso)

# %%
print('el p_value de nuestro test es {}'.format(resultado.pvalue))
# Out:
# el p_value de nuestro test es 0.010391243081223555

# %% [markdown]
# #JointPlot

# %%
tarjetas.head()
# Out:
#    Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0    6022               Si      2. Universidad     Casado/a    24
# 1   36132               Si      2. Universidad    Soltero/a    26
# 2   27099               Si      2. Universidad    Soltero/a    34
# 3   15055               Si      2. Universidad     Casado/a    37
# 4  150550               No  3. Post-graduacion    Soltero/a    29
#
#    Valor_factura  Valor_pago  Moroso        ui rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.jointplot(x='Edad', y='Limite', data= tarjetas)

# %%
#usando kde
sns.jointplot(x='Edad', y='Limite', data= tarjetas, kind='kde')

# %%
#usando hex
sns.jointplot(x='Edad', y='Limite', data= tarjetas, kind='hex')

# %%
#con hue
#usando kde
sns.jointplot(x='Edad', y='Limite', data= tarjetas, kind='kde', hue='Moroso')

# %%
#ejemplo alura
sns.jointplot(x='Edad', y='ui', data=tarjetas, kind='scatter')

# %% [markdown]
# #PairPlot

# %%
#decripcion de tarjetas
tarjetas.describe()
# Out:
#               Limite         Edad  Valor_factura    Valor_pago       Moroso  \
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.078000
# std     39424.407462     9.274955   20722.582831   5296.771686     0.268261
# min      3011.000000    21.000000      27.701200      0.000000     0.000000
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.000000
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.000000
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.000000
# max    210770.000000    75.000000  141792.506500  97022.850800     1.000000
#
#                 ui
# count  1500.000000
# mean      0.388237
# std       0.341923
# min       0.000188
# 25%       0.049209
# 50%       0.308976
# 75%       0.704090
# max       0.998010

# %%
#analisis con pairplot
sns.pairplot(data=tarjetas);

# %%
sns.pairplot(data=tarjetas, hue='Escolaridad', palette='cividis')

# %%
type(tarjetas)
# Out:
# pandas.core.frame.DataFrame

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos.to_csv('test.csv')

# %%
tarjetas
# Out:
#       Limite Cuenta_corriente         Escolaridad Estado_civil  Edad  \
# 0       6022               Si      2. Universidad     Casado/a    24
# 1      36132               Si      2. Universidad    Soltero/a    26
# 2      27099               Si      2. Universidad    Soltero/a    34
# 3      15055               Si      2. Universidad     Casado/a    37
# 4     150550               No  3. Post-graduacion    Soltero/a    29
# ...      ...              ...                 ...          ...   ...
# 1495   54198               Si  3. Post-graduacion    Soltero/a    27
# 1496   45165               No      2. Universidad     Casado/a    55
# 1497   78286               No  3. Post-graduacion    Soltero/a    34
# 1498    6022               No      2. Universidad     Casado/a    44
# 1499  183671               No  3. Post-graduacion    Soltero/a    31
#
#       Valor_factura  Valor_pago  Moroso        ui rango_edad
# 0          934.0122      0.0000       1  0.155100      20-30
# ...

# %%
datos
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
tarjetas.to_csv('/content/creditos_finales.csv', sep=';', index=False)
