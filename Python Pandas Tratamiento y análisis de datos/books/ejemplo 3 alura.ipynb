# %%
import pandas as pd
alumnos = pd.DataFrame({
'Nombre': ['Ary', 'Katia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'],
'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'],
'Edad': [15, 27, 56, 32, 42, 21, 19, 35],
'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6]},
columns = ['Nombre', 'Edad', 'Sexo', 'Notas'])
alumnos
# Out:
#    Nombre  Edad Sexo  Notas
# 0     Ary    15    M    7.5
# 1   Katia    27    F    2.5
# 2   Denis    56    M    5.0
# 3    Beto    32    M   10.0
# 4   Bruna    42    F    8.2
# 5    Dara    21    F    7.0
# 6  Carlos    19    M    6.0
# 7   Alice    35    F    5.6

# %%
alumnos['Notas-Média(Notas)'] = alumnos['Notas'].apply(lambda x: x - alumnos['Notas'].mean())
alumnos
# Out:
#    Nombre  Edad Sexo  Notas          Rango Edad  Notas-Média(Notas)
# 0     Ary    15    M    7.5   Menor que 20 años               1.025
# 1   Katia    27    F    2.5  Entre 20 y 40 años              -3.975
# 2   Denis    56    M    5.0   Mayor que 40 años              -1.475
# 3    Beto    32    M   10.0  Entre 20 y 40 años               3.525
# 4   Bruna    42    F    8.2   Mayor que 40 años               1.725
# 5    Dara    21    F    7.0  Entre 20 y 40 años               0.525
# 6  Carlos    19    M    6.0   Menor que 20 años              -0.475
# 7   Alice    35    F    5.6  Entre 20 y 40 años              -0.875

# %%
alumnos['Rango Edad'] = alumnos['Edad'].apply(lambda x: 'Menor que 20 años' if x < 20
        else ('Entre 20 y 40 años' if (x >= 20 and x <= 40)
            else 'Mayor que 40 años'))
alumnos
# Out:
#    Nombre  Edad Sexo  Notas          Rango Edad  Notas-Média(Notas)
# 0     Ary    15    M    7.5   Menor que 20 años               1.025
# 1   Katia    27    F    2.5  Entre 20 y 40 años              -3.975
# 2   Denis    56    M    5.0   Mayor que 40 años              -1.475
# 3    Beto    32    M   10.0  Entre 20 y 40 años               3.525
# 4   Bruna    42    F    8.2   Mayor que 40 años               1.725
# 5    Dara    21    F    7.0  Entre 20 y 40 años               0.525
# 6  Carlos    19    M    6.0   Menor que 20 años              -0.475
# 7   Alice    35    F    5.6  Entre 20 y 40 años              -0.875

# %%
alumnos['Notas-Média(Notas)'] = alumnos.Notas - alumnos.Notas.mean()
alumnos
# Out:
#    Nombre  Edad Sexo  Notas          Rango Edad  Notas-Média(Notas)
# 0     Ary    15    M    7.5   Menor que 20 años               1.025
# 1   Katia    27    F    2.5  Entre 20 y 40 años              -3.975
# 2   Denis    56    M    5.0   Mayor que 40 años              -1.475
# 3    Beto    32    M   10.0  Entre 20 y 40 años               3.525
# 4   Bruna    42    F    8.2   Mayor que 40 años               1.725
# 5    Dara    21    F    7.0  Entre 20 y 40 años               0.525
# 6  Carlos    19    M    6.0   Menor que 20 años              -0.475
# 7   Alice    35    F    5.6  Entre 20 y 40 años              -0.875
